# %% [markdown]
# ## Реализовать программу, которая позволяет играть в шахматы на компьютере.
# ##Взаимодействие с программой производится через консоль (базовый вариант). Игровое поле изображается в виде 8 текстовых строк, плюс строки с буквенным обозначением столбцов (см. пример на Рис. 1) и перерисовывается при каждом изменении состояния поля. При запросе данных от пользователя программа сообщает, что ожидает от пользователя (например, позицию фигуры для следующего хода белыми; целевую позицию выбранной фигуры) и проверяет корректность ввода (допускаются только ходы соответствующие правилам шахмат; поддержка рокировки, сложных правил для пешек и проверки мата вынесена в отдельные пункты). Программа должна считать количество сделанных ходов.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
board = [[' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' '],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         ['8', '|', 'r', 'n', 'b', 'q', 'k', 'b', 'n', 'r', '|', '8'],
         ['7', '|', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', '|', '7'],
         ['6', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '6'],
         ['5', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '5'],
         ['4', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '4'],
         ['3', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '3'],
         ['2', '|', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', '|', '2'],
         ['1', '|', 'R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R', '|', '1'],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         [' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' ']]
count = 0
game = True
def print_board(board): 
  for i in board:
    for j in i:
      print(j, end = ' ')
    print()
print_board(board)
print()

def correct_input(hod):
  if len(hod)!=3 or (hod[1]).lower()!='на' or len(hod[0])!=2 or len(hod[2])!=2 or (hod[0][0] not in 'ABCDEFGH') or (hod[2][0] not in 'ABCDEFGH') or (hod[0][1] not in '12345678') or (hod[2][1] not in '12345678'):
    while len(hod)!=3 or (hod[1]).lower()!='на'or len(hod[0])!=2 or len(hod[2])!=2 or (hod[0][0] not in 'ABCDEFGH') or (hod[2][0] not in 'ABCDEFGH') or (hod[0][1] not in '12345678') or (hod[2][1] not in '12345678'):
      hod = input('Повторите ход--> ').split()
      print()
  return hod


def coord1(hod):
  for i in board:
    for j in i:
      if hod[0][1] == '1':
        k = 9
      if hod[0][1] == '2':
        i = 8
      if hod[0][1] == '3':
        i = 7
      if hod[0][1] == '4':
        i = 6
      if hod[0][1] == '5':
        i = 5
      if hod[0][1] == '6':
        i = 4
      if hod[0][1] == '7':
        i = 3
      if hod[0][1] == '8':
        i = 2
      if hod[0][0] == 'A':
        j = 2
      if hod[0][0] == 'B':
        j = 3
      if hod[0][0] == 'C':
        j = 4
      if hod[0][0] == 'D':
        j = 5
      if hod[0][0] == 'E':
        j = 6
      if hod[0][0] == 'F':
        j = 7
      if hod[0][0] == 'G':
        j = 8
      if hod[0][0] == 'H':
        j = 9
  return board[i][j], i, j

   
def coord2(hod):
  for i in board:
    for j in i:
      if hod[2][1] == '1':
          i = 9
      if hod[2][1] == '2':
          i = 8
      if hod[2][1] == '3':
          i = 7
      if hod[2][1] == '4':
          i = 6
      if hod[2][1] == '5':
          i = 5
      if hod[2][1] == '6':
          i = 4
      if hod[2][1] == '7':
          i = 3
      if hod[2][1] == '8':
          i = 2
      if hod[2][0] == 'A':
          j = 2
      if hod[2][0] == 'B':
          j = 3
      if hod[2][0] == 'C':
          j = 4
      if hod[2][0] == 'D':
          j = 5
      if hod[2][0] == 'E':
          j = 6
      if hod[2][0] == 'F':
          j = 7
      if hod[2][0] == 'G':
          j = 8
      if hod[2][0] == 'H':
          j = 9
  return board[i][j],i, j

while game == True:
  hod = input('Введите ход --> ').split()
  print()

  if hod == ['СТОП']:
    game == False
    break  
  else:
    correct_input(hod)
    coord1(hod)
    fig1, i1, j1 = coord1(hod)
    coord2(hod)
    fig2, i2, j2 = coord2(hod)

  if count%2 == 0:
    print('Ход заглавных')
    print()
    if (fig1 == 'p' or fig1 == 'r' or fig1 == 'n' or fig1 == 'b' or fig1 == 'q' or fig1 == 'k'):
      while (fig1 == 'p' or fig1 == 'r' or fig1 == 'n' or fig1 == 'b' or fig1 == 'q' or fig1 == 'k'):
        hod = input('Сейчас ходят заглавные ').split()
        correct_input(hod)
        coord1(hod)
        fig1, i1, j1 = coord1(hod)
        coord2(hod)
        fig2, i2, j2 = coord2(hod)

  elif count%2 != 0:   
    print('Ход маленьких')
    print()
    if (fig1 == 'P' or fig1 == 'R' or fig1 == 'N' or fig1 == 'B' or fig1 == 'Q' or fig1 == 'K'):
      while (fig1 == 'P' or fig1 == 'R' or fig1 == 'N' or fig1 == 'B' or fig1 == 'Q' or fig1 == 'K'):
        hod = input('Сейчас ходят маленькие ').split()
        correct_input(hod)
        coord1(hod)
        fig1, i1, j1 = coord1(hod)
        coord2(hod)
        fig2, i2, j2 = coord2(hod)



  if (fig1 == 'K' and fig2 == 'R') or (fig1 == 'R' and fig2 == 'K') or (fig1 == 'k' and fig2 == 'r') or (fig1 == 'r' and fig2 == 'k'):
    def rokirovka(fig1, fig2):
      if (fig1 == 'K' and fig2 == 'R'): 
        if  i1 == 9 and j1 == 6 and i2 == 9 and j2 == 2:   #длинная рокировка для заглавных (Король на ладью)
          if board[9][3] == '.' and board[9][4] == '.'and  board[9][5] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1-2] = 'K'
            board[i2][j2+3] = 'R'
        elif  i1 == 9 and j1 == 6 and i2 == 9 and j2 == 9: #короткая рокировка для заглавных (Король на Ладью)
          if board[9][7] == '.' and board[9][8] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1+2] = 'K'
            board[i2][j2-2] = 'R'                        
      elif (fig1 == 'R' and fig2 == 'K'):
        if  i1 == 9 and j1 == 2 and i2 == 9 and j2 == 6: #длинная рокировка для заглавных (Ладья на Короля)
          if board[9][3] == '.' and board[9][4] == '.'and  board[9][5] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1+3] = 'R'
            board[i2][j2-2] = 'K'
        elif  i1 == 9 and j1 == 9 and i2 == 9 and j2 == 6: #короткая рокировка для заглавных (Ладья на Короля)
          if board[9][7] == '.' and board[9][8] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1-2] = 'R'
            board[i2][j2+2] = 'K' 

      elif (fig1 == 'k' and fig2 == 'r'): #длинная рокировка для маленьких (Король на ладью)
        if i1 == 2 and j1 == 6 and i2 == 2 and j2 == 2:
          if board[2][3] == '.' and board[2][4] == '.'and  board[2][5] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1-2] = 'k'
            board[i2][j2+3] = 'r'   
        elif  i1 == 2 and j1 == 6 and i2 == 2 and j2 == 9: #короткая рокировка для маленьких (Король на Ладью)
          if board[2][7] == '.' and board[2][8] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1+2] = 'k'
            board[i2][j2-2] = 'r'       

      elif (fig1 == 'r' and fig2 == 'k'):    #длинная рокировка для маленьких (Ладья на короля)
        if  i1 == 2 and j1 == 2 and i2 == 2 and j2 == 6:
          if board[2][3] == '.' and board[2][4] == '.'and  board[2][5] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1+3] = 'r'
            board[i2][j2-2] = 'k'      
        elif  i1 == 2 and j1 == 9 and i2 == 2 and j2 == 6: #короткая рокировка для маленьких (Ладья на Короля)
          if board[2][7] == '.' and board[2][8] == '.':
            board[i1][j1] = '.'
            board[i2][j2] = '.'
            board[i1][j1-2] = 'r'
            board[i2][j2+2] = 'k' 
                         
      else:
        print('Рокировка невозможна ')
        print()
      print(print_board(board))
    rokirovka(fig1, fig2)
    count+=1
    print()

    

  elif fig1 == 'N' or fig1 == 'n':
    def konya(fig1):
      if fig1 == 'N': 
        if (abs(i1-i2)==1 and abs(j1-j2)==2) or (abs(i1-i2)==2 and abs(j1-j2)==1):
          if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q' and fig2 != 'K'):
            board[i1][j1] = '.'
            board[i2][j2] = 'N'
          else:
            print('Неверный ход ')
            print()
        else:
          print('Неверный ход ')
          print()
      if fig1 == 'n': 
        if (abs(i1-i2)==1 and abs(j1-j2)==2) or (abs(i1-i2)==2 and abs(j1-j2)==1):
          if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q' and fig2 != 'k'):
            board[i1][j1] = '.'
            board[i2][j2] = 'n'
          else:
            print('Неверный ход ')
            print()
        else:
          print('Неверный ход ')
          print()
      print(print_board(board))
    konya(fig1)
    count += 1
    print()

  elif fig1 == 'P' or fig1 == 'p':
    def peshka(fig1):
      if fig1 == 'P':
        if fig2 == '.':
          if i1-i2 == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'P'
          elif i1-i2 == 2:
            if i1 == 3 or i1 == 8:
              board[i1][j1] = '.'
              board[i2][j2] = 'P'
            else:
              print('Неверный ход')
              print() 
          else:
            print('Неверный ход')
            print()                         
        elif (fig2 == 'p' or fig2 == 'r' or fig2 == 'n' or fig2 == 'b' or fig2 == 'q' or fig2 == 'k'):
          if i1-i2 == 1 and abs(j1-j2) == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'P'  
          else:
            print('Неверный ход ')
            print()       
        else:
            print('Неверный ход ')
            print()          

      if fig1 == 'p':
        if fig2 == '.':
          if i2-i1 == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'p'  
          elif i2-i1 == 2:
            if i1 == 8 or i1 == 3:
              board[i1][j1] = '.'
              board[i2][j2] = 'p'
            else:
              print('Неверный ход')
              print() 
          else:
            print('Неверный ход')
            print()                    
        elif (fig2 == 'P' or fig2 == 'R' or fig2 == 'N' or fig2 == 'B' or fig2 == 'Q' or fig2 == 'K'):
          if i2-i1 == 1 and abs(j1-j2) == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'p'            
          else:
            print('Неверный ход')
            print()
        else:
            print('Неверный ход ')
            print()            

      print(print_board(board))
    peshka(fig1)
    count += 1
    print()
 

  elif fig1 == 'K' or fig1 == 'k':
    def king(fig1):
      if fig1 == 'K':
        if (abs(i2-i1) == 1 and abs(j2-j1) == 1) or (abs(i2-i1) == 1) or (abs(j2-j1) == 1):
            if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q'):
              board[i1][j1] = '.'
              board[i2][j2] = 'K'
            else:
              print('Неверный ход ')
              print()
        else:
          print('Неверный ход ')
          print()     
      if fig1 == 'k':
        if (abs(i2-i1) == 1 and abs(j2-j1) == 1) or (abs(i2-i1) == 1) or (abs(j2-j1) == 1):
            if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q'):
              board[i1][j1] = '.'
              board[i2][j2] = 'k'
            else:
              print('Неверный ход ')
              print()
        else:
          print('Неверный ход ')
          print()  
      print(print_board(board))
    king(fig1)
    count += 1
    print()    

  elif fig1 == 'R' or fig1 == 'r':
    def ladya(fig1):
      if fig1 == 'R':
        if (i1 == i2) or (j1 == j2):
            if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q' and fig2 != 'K'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'R'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print()
      if fig1 == 'r':
        if (i1 == i2) or (j1 == j2):
            if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q' or fig2 != 'k'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'r'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print() 
      print(print_board(board))
    ladya(fig1)
    count += 1
    print()    

  elif fig1 == 'B' or fig1 == 'b':
    def slon(fig1):
      if fig1 == 'B':
        if abs(i1-i2) == abs(j2-j1):
            if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q' and fig2 != 'K'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'B'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print()
      if fig1 == 'b':
        if abs(i2-i1) == abs(j1-j2):
            if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q' or fig2 != 'k'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'b'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print()   
      print(print_board(board))
    slon(fig1)
    count+=1
    print()   

  elif fig1 == 'Q' or fig1 == 'q':
    def queen(fig1):
      if fig1 == 'Q':
        if (abs(i1-i2) == abs(j2-j1)) or (i2 == i1) or (j2 == j1):
            if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'K'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'Q'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print()   
      if fig1 == 'q':
        if (abs(i1-i2) == abs(j2-j1)) or (i2 == i1) or (j2 == j1):
            if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'k'):          
                board[i1][j1] = '.'
                board[i2][j2] = 'q'          
            else:
                print('Неверный ход ')
                print()
        else:
          print('Неверный ход ')
          print()          
      print(print_board(board))
    queen(fig1)
    count += 1
    print()
  print('Количество ходов = ', count)
  print()
# Out:
#   | A B C D E F G H |
# _ | _ _ _ _ _ _ _ _ | _
# 8 | r n b q k b n r | 8
# 7 | p p p p p p p p | 7
# 6 | . . . . . . . . | 6
# 5 | . . . . . . . . | 5
# 4 | . . . . . . . . | 4
# 3 | . . . . . . . . | 3
# 2 | P P P P P P P P | 2
# 1 | R N B Q K B N R | 1
# _ | _ _ _ _ _ _ _ _ | _
#   | A B C D E F G H |

# %%
2

# %% [markdown]
# ## Вывод доски

# %%
board = [[' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' '],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         ['8', '|', 'r', 'n', 'b', 'q', 'k', 'b', 'n', 'r', '|', '8'],
         ['7', '|', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', '|', '7'],
         ['6', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '6'],
         ['5', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '5'],
         ['4', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '4'],
         ['3', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '3'],
         ['2', '|', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', '|', '2'],
         ['1', '|', 'R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R', '|', '1'],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         [' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' ']]
for i in board:
  for j in i:
    print(j, end = ' ')
  print()
# Out:
#   | A B C D E F G H |
# _ | _ _ _ _ _ _ _ _ | _
# 8 | r n b q k b n r | 8
# 7 | p p p p p p p p | 7
# 6 | . . . . . . . . | 6
# 5 | . . . . . . . . | 5
# 4 | . . . . . . . . | 4
# 3 | . . . . . . . . | 3
# 2 | P P P P P P P P | 2
# 1 | R N B Q K B N R | 1
# _ | _ _ _ _ _ _ _ _ | _
#   | A B C D E F G H |

# %% [markdown]
# ## Проверка на корректность ввода

# %%
  hod = input('Введите ход --> ').split()
  if len(hod)!=3 or (hod[1]).lower()!='на' or len(hod[0])!=2 or len(hod[2])!=2 or (hod[0][0] not in 'ABCDEFGH') or (hod[2][0] not in 'ABCDEFGH') or (hod[0][1] not in '12345678') or (hod[2][1] not in '12345678'):
    while len(hod)!=3 or (hod[1]).lower()!='на'or len(hod[0])!=2 or len(hod[2])!=2 or (hod[0][0] not in 'ABCDEFGH') or (hod[2][0] not in 'ABCDEFGH') or (hod[0][1] not in '12345678') or (hod[2][1] not in '12345678'):
      hod=input('Повторите ход--> ').split()

# %% [markdown]
# ## Определение координат

# %%
  for i in board:
    for j in i:
      if hod[0][1] == '1':
        i = 9
      if hod[0][1] == '2':
        i = 8
      if hod[0][1] == '3':
        i = 7
      if hod[0][1] == '4':
        i = 6
      if hod[0][1] == '5':
        i = 5
      if hod[0][1] == '6':
        i = 4
      if hod[0][1] == '7':
        i = 3
      if hod[0][1] == '8':
        i = 2
      if hod[0][0] == 'A':
        j = 0
      if hod[0][0] == 'B':
        j = 1
      if hod[0][0] == 'C':
        j = 2
      if hod[0][0] == 'D':
        j = 3
      if hod[0][0] == 'E':
        j = 4
      if hod[0][0] == 'F':
        j = 5
      if hod[0][0] == 'G':
        j = 6
      if hod[0][0] == 'H':
        j = 7
  fig1 = board[i][j]
  i1 = i
  j1 = j
  for i in board:
    for j in i:
      if hod[2][1] == '1':
        i = 9
      if hod[2][1] == '2':
        i = 8
      if hod[2][1] == '3':
        i = 7
      if hod[2][1] == '4':
        i = 6
      if hod[2][1] == '5':
        i = 5
      if hod[2][1] == '6':
        i = 4
      if hod[2][1] == '7':
        i = 3
      if hod[2][1] == '8':
        i = 2
      if hod[2][0] == 'A':
        j = 0
      if hod[2][0] == 'B':
        j = 1
      if hod[2][0] == 'C':
        j = 2
      if hod[2][0] == 'D':
        j = 3
      if hod[2][0] == 'E':
        j = 4
      if hod[2][0] == 'F':
        j = 5
      if hod[2][0] == 'G':
        j = 6
      if hod[2][0] == 'H':
        j = 7
  fig2 = board[i][j]
  i2 = i
  j2 = j

# %% [markdown]
# ## Функция для коня

# %%
def konya(fig1):
  if fig1 == 'N': 
    if (abs(i1-i2)==1 and abs(j1-j2)==2) or (abs(i1-i2)==2 and abs(j1-j2)==1):
      if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q' and fig2 != 'K'):
        board[i1][j1] = '.'
        board[i2][j2] = 'N'
      else:
        print('Неверный ход ')
    else:
      print('Неверный ход ')
  if fig1 == 'n': 
    if (abs(i1-i2)==1 and abs(j1-j2)==2) or (abs(i1-i2)==2 and abs(j1-j2)==1):
      if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q' and fig2 != 'k'):
        board[i1][j1] = '.'
        board[i2][j2] = 'n'
      else:
        print('Неверный ход ')
    else:
      print('Неверный ход ')
  for i in board:
    for j in i:
      print(j, end = ' ')
    print()  
konya(fig1)
# Out:
# A B C D E F G H
# _ _ _ _ _ _ _ _
# r . b q k b n r
# p p p p p p p p
# . . n . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# _ _ _ _ _ _ _ _
# A B C D E F G H

# %% [markdown]
# ## Функция для пешки

# %%
  elif fig1 == 'P' or fig1 == 'p':
    def peshka(fig1):
      if fig1 == 'P':
        if fig2 == '.':
          if i1-i2 == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'P'
          else:
            print('Неверный код')
            print()
        if (fig2 == 'p' or fig2 == 'r' or fig2 == 'n' or fig2 == 'b' or fig2 == 'q' or fig2 == 'k'):
          if i1-i2 == 1 and abs(j1-j2) == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'P'           
          else:
            print('Неверный ход ')
            print()
        else:
            print('Неверный ход ')
            print()
      if fig1 == 'p':
        if fig2 == '.':
          if i2-i1 == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'p'
          else:
            print('Неверный код')
            print()
        if (fig2 == 'P' or fig2 == 'R' or fig2 == 'N' or fig2 == 'B' or fig2 == 'Q' or fig2 == 'K'):
          if i2-i1 == 1 and abs(j1-j2) == 1:
            board[i1][j1] = '.'
            board[i2][j2] = 'p'           
          else:
            print('Неверный ход ')
            print()
        else:
            print('Неверный ход ')
            print()
      print(print_board(board))
    peshka(fig1)
    print()

# %% [markdown]
# ## Функция для короля

# %%
  elif fig1 == 'K' or fig1 == 'k':
    def king(fig1):
      if fig1 == 'K':
        if (abs(i2-i1) == 1 and abs(j2-j1) == 1) or (abs(i2-i1) == 1) or (abs(j2-j1) == 1):
            if (fig2 != 'P' and fig2 != 'R' and fig2 != 'N' and fig2 != 'B' and fig2 != 'Q'):
              board[i1][j1] = '.'
              board[i2][j2] = 'K'
            else:
              print('Неверный ход ')
              print()
        else:
          print('Неверный ход ')
          print()     
      if fig1 == 'k':
        if (abs(i2-i1) == 1 and abs(j2-j1) == 1) or (abs(i2-i1) == 1) or (abs(j2-j1) == 1):
            if (fig2 != 'p' and fig2 != 'r' and fig2 != 'n' and fig2 != 'b' and fig2 != 'q'):
              board[i1][j1] = '.'
              board[i2][j2] = 'k'
            else:
              print('Неверный ход ')
              print()
        else:
          print('Неверный ход ')
          print()  
      print(print_board(board))
    king(fig1)
    print()

# %%
board = [[' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' '],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         ['8', '|', 'r', 'n', 'b', 'q', 'k', 'b', 'n', 'r', '|', '8'],
         ['7', '|', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', '|', '7'],
         ['6', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '6'],
         ['5', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '5'],
         ['4', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '4'],
         ['3', '|', '.', '.', '.', '.', '.', '.', '.', '.', '|', '3'],
         ['2', '|', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', '|', '2'],
         ['1', '|', 'R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R', '|', '1'],
         ['_', '|', '_', '_', '_', '_', '_', '_', '_', '_', '|', '_'],
         [' ', '|', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', '|', ' ']]
for i in board:
  for j in i:
    print(j, end = ' ')
  print()
# Out:
#   | A B C D E F G H |
# _ | _ _ _ _ _ _ _ _ | _
# 8 | r n b q k b n r | 8
# 7 | p p p p p p p p | 7
# 6 | . . . . . . . . | 6
# 5 | . . . . . . . . | 5
# 4 | . . . . . . . . | 4
# 3 | . . . . . . . . | 3
# 2 | P P P P P P P P | 2
# 1 | R N B Q K B N R | 1
# _ | _ _ _ _ _ _ _ _ | _
#   | A B C D E F G H |
